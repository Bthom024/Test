# %%
import random
pay=input("Enter $2 ('2') to play the powerball lottery. Otherwise enter '0' to quit. : ")
while pay=='2':
    choice = input("Enter 'R' to first generate a list of winning numbers and 'O' to begin picking your powerball numbers:")
    if choice == ('R'):
        one = random.randint(1,69)
        two = random.randint(1,69)
        three = random.randint(1,69)
        four = random.randint(1,69)
        five = random.randint(1,69)
        powerball = random.randint(1,26)
        winning_num=one,two,three,four,five,powerball
        choice = input("Enter 'R' to first generate a list of winning numbers and 'O' to begin picking your powerball numbers:")
    if choice == ('O'):
        one_1 = int(input("Please pick your 1st number, between 1 and 69: "))
        if one_1>69:
            print("Invalid input, please pick a number between 1 and 69.")
            one_1 = int(input("Please pick your 1st number, between 1 and 69: "))
        if one_1<1:
            print("Invalid input, please pick a number between 1 and 69.")
            one_1 = int(input("Please pick your 1st number, between 1 and 69: "))
            
        two_2 = int(input("Please pick your 2nd number, between 1 and 69: "))
        if two_2>69:
            print("Invalid input, please pick a number between 1 and 69.")
            two_2 = int(input("Please pick your 2nd number, between 1 and 69: "))
        if two_2<1:
            print("Invalid input, please pick a number between 1 and 69.")
            two_2 = int(input("Please pick your 2nd number, between 1 and 69: "))
            
        three_3 = int(input("Please pick your 3rd number, between 1 and 69: "))
        if three_3>69:
            print("Invalid input, please pick a number between 1 and 69.")
            three_3 = int(input("Please pick your 3rd number, between 1 and 69: "))
        if three_3<1:
            print("Invalid input, please pick a number between 1 and 69.")
            three_3 = int(input("Please pick your 3rd number, between 1 and 69: "))
            
        four_4 = int(input("Please pick your 4th number, between 1 and 69: "))
        if four_4>69:
            print("Invalid input, please pick a number between 1 and 69.")
            four_4 = int(input("Please pick your 4th number, between 1 and 69: "))
        if four_4<1:
            print("Invalid input, please pick a number between 1 and 69.")
            four_4 = int(input("Please pick your 4th number, between 1 and 69: "))
            
        five_5 = int(input("Please pick your 5th number, between 1 and 69: "))
        if five_5>69:
            print("Invalid input, please pick a number between 1 and 69.")
            five_5 = int(input("Please pick your 5th number, between 1 and 69: "))
        if five_5<1:
            print("Invalid input, please pick a number between 1 and 69.")
            five_5 = int(input("Please pick your 5th number, between 1 and 69: "))
            
        powerball_p = int(input("Please pick your Powerball number, between 1 and 26: "))
        if powerball_p>26:
            print("Invalid input, please pick a number between 1 and 69.")
            powerball_p = int(input("Please pick your Powerball number, between 1 and 26: "))
        if powerball_p<1:
            print("Invalid input, please pick a number between 1 and 69.")
            powerball_p = int(input("Please pick your Powerball number, between 1 and 26: "))
        
    while True:
        if one==one_1:
            Run=True
        else:
            Run=False
            break
        if two==two_2:
            Run=True
        else:
            Run=False
            break
        if three==three_3:
            Run=True
        else:
            Run=False
            break
        if four==four_4:
            Run=True
        else:
            Run=False
            break
        if five==five_5:
            Run=True
        else:
            Run=False
            break
        if powerball==powerball_p:
            Run=True
        else:
            Run=False
            break
        break
    if (Run):
        print("You won the jackpot!!!")
    else:
        print("You lost $2.")
    pay=input("Enter $2 ('2') to play the powerball lottery. Otherwise enter '0' to quit. : ")
# Out:
# Enter $2 ('2') to play the powerball lottery. Otherwise enter '0' to quit. : 2
# Enter 'R' to first generate a list of winning numbers and 'O' to begin picking your powerball numbers:R
# Enter 'R' to first generate a list of winning numbers and 'O' to begin picking your powerball numbers:O
# Please pick your 1st number, between 1 and 69: 65
# Please pick your 2nd number, between 1 and 69: 65
# Please pick your 3rd number, between 1 and 69: 65
# Please pick your 4th number, between 1 and 69: 65
# Please pick your 5th number, between 1 and 69: 65
# Please pick your Powerball number, between 1 and 26: 26
# You lost $2.
# Enter $2 ('2') to play the powerball lottery. Otherwise enter '0' to quit. : 0
